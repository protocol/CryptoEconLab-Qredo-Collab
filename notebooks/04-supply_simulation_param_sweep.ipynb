# %% [markdown]
# # Qredo tokenomics simulation - parameter sweep
#
# #### Maria Silva, June 2023
#
# ## 1. Imports

# %%
import os
import timeit
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
code_dir = os.path.realpath(os.path.join(os.getcwd(), ".."))

import sys
sys.path.append(code_dir)

from mechaqredo.params import default_params_dict
from mechaqredo.sim import run_param_sweep_sim

# %% [markdown]
# ## 2. Set parameters

# %%
forecast_length = 365*3
data_dict_n_samples = 50
param_ranges_dict = {
    "tipping_rate": [0.1, 0.3],
    "validator_reward_share": [0.2, 0.5, 0.8],
    "staking_rewards_vesting_decay_rate": [np.log(2) / (4.0 * 365), np.log(2) / (2.0 * 365)],
}
file = os.path.realpath("../data/balances.csv")
wallet_df = pd.read_csv(file)
params_dict = default_params_dict(forecast_length)
params_dict["wallet_balances_vec"] = wallet_df["balance"].values

# %% [markdown]
# ## 3. Run parameter sweep

# %%
start = timeit.default_timer()
sweep_df = run_param_sweep_sim(
    forecast_length,
    params_dict,
    param_ranges_dict,
    data_dict_n_samples
)
stop = timeit.default_timer()
print("Run time for single sim: ", stop - start)
print("")
sweep_df.head()
# Out:
# Run time for single sim:  7.273587291
#    iteration   circ_supply   day_burned    day_vested    day_locked
# 0          0  5.122638e+08  350000004.0  5.050000e+08  1.777362e+08  \
# 1          1  5.523435e+08          4.0  2.551592e+05  4.731250e+03
# 2          2  5.635266e+08          4.0  9.488407e+04  1.597441e+07
# 3          3  5.699967e+08          4.0  9.483904e+04  1.086770e+07
# 4          4  5.788771e+08          4.0  5.251131e+06  6.939859e+06
#
#    day_released  staking_rewards_vested  staking_rewards_ecosystem
# 0  1.750000e+08                0.000000               0.000000e+00  \
# 1  3.982927e+07            94929.132588               3.982927e+07
# 2  2.706255e+07            94884.074887               2.706255e+07
# 3  1.724298e+07            94839.038572               1.724298e+07
# 4  1.056916e+07            94794.023634               1.056915e+07
#
#    total_staking_rewards  validators_rewards  ...   staking_tvl   n_txs
# 0           0.000000e+00        0.000000e+00  ...  6.773243e+07  8000.0  \
# 1           3.992420e+07        7.984840e+06  ...  6.773343e+07  8000.0
# 2           2.715743e+07        5.431486e+06  ...  8.370411e+07  8000.0
# 3           1.733782e+07        3.467564e+06  ...  9.456808e+07  8000.0
# 4           1.066395e+07        2.132790e+06  ...  1.015042e+08  8000.0
#
#    token_price  service_fees  n_validators  day_inflation  year_inflation
# 0         0.08        3000.0           6.0            NaN             NaN  \
# 1         0.08        3000.0           6.0       0.078240             NaN
# 2         0.08        3000.0           6.0       0.020246             NaN
# 3         0.08        3000.0           6.0       0.011481             NaN
# 4         0.08        3000.0           6.0       0.015580             NaN
#
#    tipping_rate  validator_reward_share  staking_rewards_vesting_decay_rate
# 0           0.1                     0.2                            0.000475
# 1           0.1                     0.2                            0.000475
# 2           0.1                     0.2                            0.000475
# 3           0.1                     0.2                            0.000475
# 4           0.1                     0.2                            0.000475
#
# [5 rows x 24 columns]
